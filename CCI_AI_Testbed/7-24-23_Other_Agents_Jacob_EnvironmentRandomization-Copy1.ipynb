# %% [markdown]
# ## 7/24: File used to test NaSim QL Agent on custom network built with scenario args AND NaSim Small Network

# %% [markdown]
# This is all some intro code just to visualize some of the settings and get a baseline. You can run through it if you want to get familiar with what the scenario arguments, agents, and training looks like.

# %%
testfile = 'data.yaml'


def writeToYAML():
    with open(testfile, 'w') as f:
        data = yaml.dump(curr_data, f, sort_keys=False, default_flow_style=False)

# %%
def print_nested_dict(dict_obj, indent = 0):
    ''' Pretty Print nested dictionary with given indent level  
    '''
    # Iterate over all key-value pairs of dictionary
    for key, value in dict_obj.items():
        # If value is dict type, then print nested dict 
        if isinstance(value, dict):
            print(' ' * indent, key, ':', '{')
            print_nested_dict(value, indent + 4)
            print(' ' * indent, '}')
        else:
            print(' ' * indent, key, ':', value)

# %%
import nasim
import json
env = nasim.generate(**scenario_args)
env = nasim.make_benchmark("huge-gen")
env = nasim.load("unreachable.yaml")
env2 = env = nasim.make_benchmark("small")


scenario_desc = env.scenario.get_description() #get_description found in scenario.py file under nasim->scenarios
scenario_dict = env.scenario.scenario_dict
#scenario_exploit_map = env.scenario.exploit_map # A nested dictionary for all exploits in scenario.
#scenario_privesc_map = env.scenario.privesc_map # A nested dictionary for all privilege escalation actions in scenario.

print("Scenario Description: ")
print_nested_dict(scenario_desc,4)

print("\nScenario Dictionary: ")
print_nested_dict(scenario_dict,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import nasim
#       2 import json
# ----> 3 env = nasim.generate(**scenario_args)
#       4 env = nasim.make_benchmark("huge-gen")
#       5 env = nasim.load("unreachable.yaml")
#
# NameError: name 'scenario_args' is not defined

# %%
#env.get_minimum_actions()

# %%
#NOW USING AGENT ABOVE INSTEAD OF IMPORTING AGENT:
#USED TO BE: from nasim.agents.ql_agent import TabularQLearningAgent

ql_agent = TabularQLearningAgent(env2, verbose=1, training_steps=500)
training_outputs = ql_agent.train()
# Out:
# Running Tabular Q-Learning with config:
# {'env': <nasim.envs.environment.NASimEnv object at 0x7f0bc6879c60>,
#  'exploration_steps': 10000,
#  'final_epsilon': 0.05,
#  'gamma': 0.99,
#  'kwargs': {},
#  'lr': 0.001,
#  'seed': None,
#  'self': <__main__.TabularQLearningAgent object at 0x7f0b2c276080>,
#  'training_steps': 500,
#  'verbose': 1}
#
# Starting training
# Training complete
#
# Episode 2:
# 	steps done = 500 / 500
# 	return = -339.0
# 	goal = False

# %% [markdown]
# ## Current Code
# Here is the main code to test/run.

# %%
# Initial scenario arguments... we will be editing the number of hosts by marking actions involving them as invalid
scenario_args2={
    "num_hosts": 5,         # Number of hosts in the network 
    
    "num_services": 3,      # Number of services on the network (ssh, ftp, http)
    
    "num_os": 2,            # Number of operatings systems on the network (windows, linux, etc)
    
    "num_processes": 2,     # Number of processes on the network (tomcat, daclsvc, etc)
    
    "num_exploits": None,   # Number of exploits to use
    
    "num_privescs": None,   # Number of privilege escalation actions
    
    "r_sensitive": 10,      # Reward for sensitive subnet documents (default 10)
    
    "r_user": 10,           # Reward for user subnet documents      (default 10)
    
    "exploit_cost": 1,      # Cost to use an exploit (default 1)
    
    "exploit_probs": 1.0,   # Sucess probability of exploits (default 1.0)
    
    "privesc_cost": 1,      # Cost of privilege escalation action (default 1)
    
    "privesc_probs": 1.0,   # Sucess probability of privilege escalation action (default 1.0)
    
    "service_scan_cost": 1, # Cost for a service scan (default 1)
    
    "os_scan_cost": 1,      # Cost for an OS scan (default 1)
    
    "subnet_scan_cost": 1,  # Cost for a subnet scan (default 1)
    
    "process_scan_cost": 1, # Cost for a process scan (default 1)
    
    "uniform": False,       # Whether to use uniform distribution or correlaed host configuration (default false)
    
    "alpha_H": 2.0,         # Scaling or concentration parameter for controlling corelation between host configurations (default 2.0)
    
    "alpha_V": 2.0,         # Scaling or concentration parameter for controlling corelation between services across host configruations (default 2.0)
    
    "lambda_V": 1.0,        # Parameter for controlling average number of services running per host configuration (default 1.0)
    
    "restrictiveness": 5,   # Maximum number of services allowed to pass through firewalls between zones (default 5)
    
    "random_goal": False,   # Whether to randomly assign the goal user host or not (default False)
    
    "base_host_value": 1,   # Value of non sensitive hosts (default 1)
    
    "host_discovery_value": 1,  # Value of discovering a host for the first time (default 1)
    
    "seed": None,           # Random number generator seed (default None)
    
    "name": None,           # Name of the scenario, one will be generated if None (default None)
    
    "step_limit": None}     # Max number of steps permitted in a single episode, None means no limit (default None)

#Scenario Generator Parameter List: https://networkattacksimulator.readthedocs.io/en/latest/reference/scenarios/generator.html#scenario-generator

# %%
# Defining Python user-defined exceptions
class SensitiveHostRemovalException(Exception):
    "Raised when selected network host cannot be removed (sensitive host needs to remain in network)"
    pass

class PublicHostRemovalException(Exception):
    "Raised when selected network host cannot be removed (public host to enter the network... specific to this configuration)"
    pass

# %%
"""An example Tabular, epsilon greedy Q-Learning Agent.

This agent does not use an Experience replay (see the 'ql_replay_agent.py')

It uses pytorch 1.5+ tensorboard library for logging (HINT: these dependencies
can be installed by running pip install nasim[dqn])

To run 'tiny' benchmark scenario with default settings, run the following from
the nasim/agents dir:

$ python ql_agent.py tiny

To see detailed results using tensorboard:

$ tensorboard --logdir runs/

To see available hyperparameters:

$ python ql_agent.py --help

Notes
-----

This is by no means a state of the art implementation of Tabular Q-Learning.
It is designed to be an example implementation that can be used as a reference
for building your own agents and for simple experimental comparisons.
"""
import random
import numpy as np
from pprint import pprint

import nasim

try:
    from torch.utils.tensorboard import SummaryWriter
except ImportError as e:
    from gymnasium import error
    raise error.DependencyNotInstalled(
        f"{e}. (HINT: you can install tabular_q_learning_agent dependencies "
        "by running 'pip install nasim[dqn]'.)"
    )


class TabularQFunction:
    """Tabular Q-Function """

    def __init__(self, num_actions):
        self.q_func = dict()
        self.num_actions = num_actions

    def __call__(self, x):
        return self.forward(x)

    def forward(self, x):
        if isinstance(x, np.ndarray):
            x = str(x.astype(int))
        if x not in self.q_func:
            self.q_func[x] = np.zeros(self.num_actions, dtype=np.float32)
        return self.q_func[x]

    def forward_batch(self, x_batch):
        return np.asarray([self.forward(x) for x in x_batch])

    def update_batch(self, s_batch, a_batch, delta_batch):
        for s, a, delta in zip(s_batch, a_batch, delta_batch):
            q_vals = self.forward(s)
            q_vals[a] += delta

    def update(self, s, a, delta):
        q_vals = self.forward(s)
        q_vals[a] += delta

    def get_action(self, x):
        return int(self.forward(x).argmax())

    def display(self):
        pprint(self.q_func)


class TabularQLearningAgent:
    """A Tabular. epsilon greedy Q-Learning Agent using Experience Replay """

    def __init__(self,
                 env,
                 seed=None,
                 lr=0.001,
                 training_steps=10000,
                 final_epsilon=0.05,
                 exploration_steps=10000,
                 gamma=0.99,
                 verbose=True,
                 **kwargs):

        # This implementation only works for flat actions
        assert env.flat_actions
        self.verbose = verbose
        if self.verbose:
            print("\nRunning Tabular Q-Learning with config:")
            pprint(locals())

        # set seeds
        self.seed = seed
        if self.seed is not None:
            np.random.seed(self.seed)

        # envirnment setup
        self.env = env

        self.num_actions = self.env.action_space.n
        self.obs_dim = self.env.observation_space.shape

        # logger setup
        self.logger = SummaryWriter()

        # Training related attributes
        self.lr = lr
        self.exploration_steps = exploration_steps
        self.final_epsilon = final_epsilon
        self.epsilon_schedule = np.linspace(
            1.0, self.final_epsilon, self.exploration_steps
        )
        self.discount = gamma
        self.training_steps = training_steps
        self.steps_done = 0

        # Q-Function
        self.qfunc = TabularQFunction(self.num_actions)

    def get_epsilon(self):
        if self.steps_done < self.exploration_steps:
            return self.epsilon_schedule[self.steps_done]
        return self.final_epsilon

    def get_egreedy_action(self, o, epsilon):
        if random.random() > epsilon:
            return self.qfunc.get_action(o)
        return random.randint(0, self.num_actions-1)

    def optimize(self, s, a, next_s, r, done):
        # get q_val for state and action performed in that state
        q_vals_raw = self.qfunc.forward(s)
        q_val = q_vals_raw[a]

        # get target q val = max val of next state
        target_q_val = self.qfunc.forward(next_s).max()
        target = r + self.discount * (1-done) * target_q_val

        # calculate error and update
        td_error = target - q_val
        td_delta = self.lr * td_error

        # optimize the model
        self.qfunc.update(s, a, td_delta)

        s_value = q_vals_raw.max()
        return td_error, s_value

    def train(self):
        if self.verbose:
            print("\nStarting training")

        num_episodes = 0
        training_steps_remaining = self.training_steps
        elems_to_avg = []
        all_avgs = []

        while self.steps_done < self.training_steps:
            ep_results = self.run_train_episode(training_steps_remaining)
            ep_return, ep_steps, goal = ep_results
            num_episodes += 1
            training_steps_remaining -= ep_steps

            self.logger.add_scalar("episode", num_episodes, self.steps_done)
            self.logger.add_scalar(
                "epsilon", self.get_epsilon(), self.steps_done
            )
            self.logger.add_scalar(
                "episode_return", ep_return, self.steps_done
            )
            self.logger.add_scalar(
                "episode_steps", ep_steps, self.steps_done
            )
            self.logger.add_scalar(
                "episode_goal_reached", int(goal), self.steps_done
            )

            if num_episodes % 10 == 0 and self.verbose:
                print(f"\nEpisode {num_episodes}:")
                print(f"\tsteps done = {self.steps_done} / "
                      f"{self.training_steps}")
                print(f"\treturn = {ep_return}")
                print(f"\tgoal = {goal}")
                print(f"\t")
    
                elems_to_avg.append(ep_return)
                
            if num_episodes % 50 == 0 and self.verbose:
                avg = (sum(elems_to_avg) / len(elems_to_avg))
                all_avgs.append(avg)

                print(f"\t")
                print(f"\tRunning_Average = {avg}")
                print(f"\t")
                
            if num_episodes % 1000 == 0 and self.verbose:
                for i in range(len(all_avgs)):
                    print("Episode " + str((i+1)*50), end=": ")
                    print(all_avgs[i])
                print(f"\t")
            
                for i in range(len(elems_to_avg)):
                    print("Episode " + str((i+1)*10), end=": ")
                    print(elems_to_avg[i])
                print(f"\t")

                for i in range(len(elems_to_avg)):
                    print(elems_to_avg[i])

        self.logger.close()
        if self.verbose:
            print("Training complete")
            print(f"\nEpisode {num_episodes}:")
            print(f"\tsteps done = {self.steps_done} / {self.training_steps}")
            print(f"\treturn = {ep_return}")
            print(f"\tgoal = {goal}")
            
            print(f"\t")
            print("Running_Average List:")
            print(f"\t")
            
            for i in range(len(all_avgs)):
                print("Episode " + str((i+1)*50), end=": ")
                print(all_avgs[i])
            print(f"\t")
            
            for i in range(len(elems_to_avg)):
                print("Episode " + str((i+1)*10), end=": ")
                print(elems_to_avg[i])
            print(f"\t")
            
            for i in range(len(elems_to_avg)):
                print(elems_to_avg[i])
            print(f"\t")

    def run_train_episode(self, step_limit):
        s, _ = self.env.reset()
        done = False
        env_step_limit_reached = False

        steps = 0
        episode_return = 0

        while not done and not env_step_limit_reached and steps < step_limit:
            a = self.get_egreedy_action(s, self.get_epsilon())

            next_s, r, done, env_step_limit_reached, _ = self.env.step(a)
            self.steps_done += 1
            td_error, s_value = self.optimize(s, a, next_s, r, done)
            self.logger.add_scalar("td_error", td_error, self.steps_done)
            self.logger.add_scalar("s_value", s_value, self.steps_done)

            s = next_s
            episode_return += r
            steps += 1

        return episode_return, steps, self.env.goal_reached()

    def run_eval_episode(self,
                         env=None,
                         render=False,
                         eval_epsilon=0.05,
                         render_mode="human"):
        if env is None:
            env = self.env

        original_render_mode = env.render_mode
        env.render_mode = render_mode

        s, _ = env.reset()
        done = False
        env_step_limit_reached = False

        steps = 0
        episode_return = 0

        line_break = "="*60
        if render:
            print("\n" + line_break)
            print(f"Running EVALUATION using epsilon = {eval_epsilon:.4f}")
            print(line_break)
            env.render()
            input("Initial state. Press enter to continue..")

        while not done and not env_step_limit_reached:
            a = self.get_egreedy_action(s, eval_epsilon)
            next_s, r, done, env_step_limit_reached, _ = env.step(a)
            s = next_s
            episode_return += r
            steps += 1
            if render:
                print("\n" + line_break)
                print(f"Step {steps}")
                print(line_break)
                print(f"Action Performed = {env.action_space.get_action(a)}")
                env.render()
                print(f"Reward = {r}")
                print(f"Done = {done}")
                print(f"Step limit reached = {env_step_limit_reached}")
                input("Press enter to continue..")

                if done or env_step_limit_reached:
                    print("\n" + line_break)
                    print("EPISODE FINISHED")
                    print(line_break)
                    print(f"Goal reached = {env.goal_reached()}")
                    print(f"Total steps = {steps}")
                    print(f"Total reward = {episode_return}")

        env.render_mode = original_render_mode
        return episode_return, steps, env.goal_reached()


if __name__ == "__main__":
    import argparse
    parser = argparse.ArgumentParser()
    parser.add_argument("env_name", type=str, help="benchmark scenario name")
    parser.add_argument("--render_eval", action="store_true",
                        help="Renders final policy")
    parser.add_argument("--lr", type=float, default=0.001,
                        help="Learning rate (default=0.001)")
    parser.add_argument("-t", "--training_steps", type=int, default=10000,
                        help="training steps (default=10000)")
    parser.add_argument("--batch_size", type=int, default=32,
                        help="(default=32)")
    parser.add_argument("--seed", type=int, default=0,
                        help="(default=0)")
    parser.add_argument("--replay_size", type=int, default=100000,
                        help="(default=100000)")
    parser.add_argument("--final_epsilon", type=float, default=0.05,
                        help="(default=0.05)")
    parser.add_argument("--init_epsilon", type=float, default=1.0,
                        help="(default=1.0)")
    parser.add_argument("-e", "--exploration_steps", type=int, default=10000,
                        help="(default=10000)")
    parser.add_argument("--gamma", type=float, default=0.99,
                        help="(default=0.99)")
    parser.add_argument("--quite", action="store_false",
                        help="Run in Quite mode")
    args = parser.parse_args()

    env = nasim.make_benchmark(
        args.env_name,
        args.seed,
        fully_obs=True,
        flat_actions=True,
        flat_obs=True
    )
    ql_agent = TabularQLearningAgent(
        env, verbose=args.quite, **vars(args)
    )
    ql_agent.train()
    ql_agent.run_eval_episode(render=args.render_eval)
# Out:
# usage: ipykernel_launcher.py [-h] [--render_eval] [--lr LR]
#                              [-t TRAINING_STEPS] [--batch_size BATCH_SIZE]
#                              [--seed SEED] [--replay_size REPLAY_SIZE]
#                              [--final_epsilon FINAL_EPSILON]
#                              [--init_epsilon INIT_EPSILON]
#                              [-e EXPLORATION_STEPS] [--gamma GAMMA] [--quite]
#                              env_name
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/jovyan/envs/nasim/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#NOW USING AGENT ABOVE INSTEAD OF IMPORTANT AGENT:
#USED TO BE: from nasim.agents.ql_agent import TabularQLearningAgent

env3 = nasim.generate(**scenario_args2)
env4 = nasim.make_benchmark("small")
baseline_ql_agent = TabularQLearningAgent(env4, verbose=1, training_steps=300000, max_episodes=2000)
baseline_ql_agent.train()
baseline_ql_agent.run_eval_episode(render_mode="human")

print("QL AGENT NOW ON scenario_args2 NETWORK")

baseline_ql_agent = TabularQLearningAgent(env4, verbose=1, training_steps=300000, max_episodes=2000) #This actually ran the small network again, scenario_args2 network done below this cell
baseline_ql_agent.train()
baseline_ql_agent.run_eval_episode(render_mode="human")
# Out:
# Running Tabular Q-Learning with config:
# {'env': <nasim.envs.environment.NASimEnv object at 0x7f45e465ee60>,
#  'exploration_steps': 10000,
#  'final_epsilon': 0.05,
#  'gamma': 0.99,
#  'kwargs': {'max_episodes': 2000},
#  'lr': 0.001,
#  'seed': None,
#  'self': <__main__.TabularQLearningAgent object at 0x7f47535b7eb0>,
#  'training_steps': 300000,
#  'verbose': 1}
#
# Starting training
#
# Episode 10:
# 	steps done = 5328 / 300000
# 	return = -347.0
# 	goal = True
#
#
# Episode 20:
# 	steps done = 13517 / 300000
# 	return = -965.0
# 	goal = False
#
#
# Episode 30:
# 	steps done = 22012 / 300000
# 	return = -150.0
# 	goal = True
#
#
# Episode 40:
# 	steps done = 29040 / 300000
# 	return = -1029.0
# 	goal = False
#
#
# Episode 50:
# 	steps done = 35554 / 300000
# 	return = -40.0
# 	goal = True
#
#
# 	Running_Average = -506.2
#
#
# Episode 60:
# 	steps done = 41017 / 300000
# 	return = -204.0
# 	goal = True
#
#
# Episode 70:
# 	steps done = 47746 / 300000
# 	return = -907.0
# 	goal = True
#
#
# Episode 80:
# 	steps done = 53228 / 300000
# 	return = -360.0
# 	goal = True
#
#
# Episode 90:
# 	steps done = 58392 / 300000
# 	return = -534.0
# 	goal = True
#
#
# Episode 100:
# 	steps done = 64458 / 300000
# 	return = -684.0
# 	goal = True
#
#
# 	Running_Average = -522.0
#
#
# Episode 110:
# 	steps done = 69508 / 300000
# 	return = -485.0
# 	goal = True
#
#
# Episode 120:
# 	steps done = 74528 / 300000
# 	return = -624.0
# 	goal = True
#
#
# Episode 130:
# 	steps done = 79242 / 300000
# 	return = -194.0
# 	goal = True
#
#
# Episode 140:
# 	steps done = 83354 / 300000
# 	return = -526.0
# 	goal = True
#
#
# Episode 150:
# 	steps done = 86613 / 300000
# 	return = 0.0
# 	goal = True
#
#
# 	Running_Average = -469.93333333333334
#
#
# Episode 160:
# 	steps done = 91092 / 300000
# 	return = -71.0
# 	goal = True
#
#
# Episode 170:
# 	steps done = 95910 / 300000
# 	return = -538.0
# 	goal = True
#
#
# Episode 180:
# 	steps done = 100373 / 300000
# 	return = -339.0
# 	goal = True
#
#
# Episode 190:
# 	steps done = 104019 / 300000
# 	return = -541.0
# 	goal = True
#
#
# Episode 200:
# 	steps done = 108433 / 300000
# 	return = -397.0
# 	goal = True
#
#
# 	Running_Average = -446.75
#
#
# Episode 210:
# 	steps done = 112287 / 300000
# 	return = 23.0
# 	goal = True
#
#
# Episode 220:
# 	steps done = 116234 / 300000
# 	return = -112.0
# 	goal = True
#
#
# Episode 230:
# 	steps done = 121104 / 300000
# 	return = 1.0
# 	goal = True
#
#
# Episode 240:
# 	steps done = 124450 / 300000
# 	return = -316.0
# 	goal = True
#
#
# Episode 250:
# 	steps done = 129049 / 300000
# 	return = -369.0
# 	goal = True
#
#
# 	Running_Average = -388.32
#
#
# Episode 260:
# 	steps done = 132232 / 300000
# 	return = -9.0
# 	goal = True
#
#
# Episode 270:
# 	steps done = 135049 / 300000
# 	return = -262.0
# 	goal = True
#
#
# Episode 280:
# 	steps done = 138097 / 300000
# 	return = 57.0
# 	goal = True
#
#
# Episode 290:
# 	steps done = 140766 / 300000
# 	return = -158.0
# 	goal = True
#
#
# Episode 300:
# 	steps done = 142428 / 300000
# 	return = 33.0
# 	goal = True
#
#
# 	Running_Average = -334.9
#
#
# Episode 310:
# 	steps done = 144768 / 300000
# 	return = -119.0
# 	goal = True
#
#
# Episode 320:
# 	steps done = 146691 / 300000
# 	return = -106.0
# 	goal = True
#
#
# Episode 330:
# 	steps done = 149405 / 300000
# 	return = -23.0
# 	goal = True
#
#
# Episode 340:
# 	steps done = 151621 / 300000
# 	return = 61.0
# 	goal = True
#
#
# Episode 350:
# 	steps done = 154118 / 300000
# 	return = -147.0
# 	goal = True
#
#
# 	Running_Average = -296.6
#
#
# Episode 360:
# 	steps done = 156100 / 300000
# 	return = -102.0
# 	goal = True
#
#
# Episode 370:
# 	steps done = 158861 / 300000
# 	return = -187.0
# 	goal = True
#
#
# Episode 380:
# 	steps done = 161115 / 300000
# 	return = 39.0
# 	goal = True
#
#
# Episode 390:
# 	steps done = 163549 / 300000
# 	return = 34.0
# 	goal = True
#
#
# Episode 400:
# 	steps done = 165818 / 300000
# 	return = -1.0
# 	goal = True
#
#
# 	Running_Average = -264.95
#
#
# Episode 410:
# 	steps done = 168242 / 300000
# 	return = -34.0
# 	goal = True
#
#
# Episode 420:
# 	steps done = 171545 / 300000
# 	return = -69.0
# 	goal = True
#
#
# Episode 430:
# 	steps done = 175760 / 300000
# 	return = -67.0
# 	goal = True
#
#
# Episode 440:
# 	steps done = 179268 / 300000
# 	return = -310.0
# 	goal = True
#
#
# Episode 450:
# 	steps done = 182371 / 300000
# 	return = -26.0
# 	goal = True
#
#
# 	Running_Average = -246.75555555555556
#
#
# Episode 460:
# 	steps done = 185764 / 300000
# 	return = -9.0
# 	goal = True
#
#
# Episode 470:
# 	steps done = 189758 / 300000
# 	return = -348.0
# 	goal = True
#
#
# Episode 480:
# 	steps done = 193048 / 300000
# 	return = -278.0
# 	goal = True
#
#
# Episode 490:
# 	steps done = 196502 / 300000
# 	return = -119.0
# 	goal = True
#
#
# Episode 500:
# 	steps done = 199845 / 300000
# 	return = -338.0
# 	goal = True
#
#
# 	Running_Average = -243.92
#
#
# Episode 510:
# 	steps done = 202726 / 300000
# 	return = -155.0
# 	goal = True
#
#
# Episode 520:
# 	steps done = 205773 / 300000
# 	return = -186.0
# 	goal = True
#
#
# Episode 530:
# 	steps done = 208747 / 300000
# 	return = -78.0
# 	goal = True
#
#
# Episode 540:
# 	steps done = 212220 / 300000
# 	return = -263.0
# 	goal = True
#
#
# Episode 550:
# 	steps done = 215447 / 300000
# 	return = -237.0
# 	goal = True
#
#
# 	Running_Average = -238.45454545454547
#
#
# Episode 560:
# 	steps done = 218220 / 300000
# 	return = -118.0
# 	goal = True
#
#
# Episode 570:
# 	steps done = 220765 / 300000
# 	return = -33.0
# 	goal = True
#
#
# Episode 580:
# 	steps done = 224047 / 300000
# 	return = -146.0
# 	goal = True
#
#
# Episode 590:
# 	steps done = 226958 / 300000
# 	return = -19.0
# 	goal = True
#
#
# Episode 600:
# 	steps done = 229704 / 300000
# 	return = -136.0
# 	goal = True
#
#
# 	Running_Average = -226.11666666666667
#
#
# Episode 610:
# 	steps done = 233504 / 300000
# 	return = -129.0
# 	goal = True
#
#
# Episode 620:
# 	steps done = 236774 / 300000
# 	return = -201.0
# 	goal = True
#
#
# Episode 630:
# 	steps done = 239630 / 300000
# 	return = -221.0
# 	goal = True
#
#
# Episode 640:
# 	steps done = 242064 / 300000
# 	return = -179.0
# 	goal = True
#
#
# Episode 650:
# 	steps done = 244792 / 300000
# 	return = -35.0
# 	goal = True
#
#
# 	Running_Average = -220.4923076923077
#
#
# Episode 660:
# 	steps done = 246549 / 300000
# 	return = 81.0
# 	goal = True
#
#
# Episode 670:
# 	steps done = 249493 / 300000
# 	return = 96.0
# 	goal = True
#
#
# Episode 680:
# 	steps done = 252605 / 300000
# 	return = 64.0
# 	goal = True
#
#
# Episode 690:
# 	steps done = 255094 / 300000
# 	return = -114.0
# 	goal = True
#
#
# Episode 700:
# 	steps done = 257610 / 300000
# 	return = -110.0
# 	goal = True
#
#
# 	Running_Average = -204.5
#
#
# Episode 710:
# 	steps done = 259701 / 300000
# 	return = -105.0
# 	goal = True
#
#
# Episode 720:
# 	steps done = 261451 / 300000
# 	return = -169.0
# 	goal = True
#
#
# Episode 730:
# 	steps done = 263294 / 300000
# 	return = 28.0
# 	goal = True
#
#
# Episode 740:
# 	steps done = 264947 / 300000
# 	return = 124.0
# 	goal = True
#
#
# Episode 750:
# 	steps done = 266590 / 300000
# 	return = -259.0
# 	goal = True
#
#
# 	Running_Average = -195.94666666666666
#
#
# Episode 760:
# 	steps done = 267865 / 300000
# 	return = 136.0
# 	goal = True
#
#
# Episode 770:
# 	steps done = 269975 / 300000
# 	return = -21.0
# 	goal = True
#
#
# Episode 780:
# 	steps done = 271178 / 300000
# 	return = 157.0
# 	goal = True
#
#
# Episode 790:
# 	steps done = 272425 / 300000
# 	return = 122.0
# 	goal = True
#
#
# Episode 800:
# 	steps done = 273447 / 300000
# 	return = -26.0
# 	goal = True
#
#
# 	Running_Average = -179.1
#
#
# Episode 810:
# 	steps done = 274442 / 300000
# 	return = 95.0
# 	goal = True
#
#
# Episode 820:
# 	steps done = 275540 / 300000
# 	return = 10.0
# 	goal = True
#
#
# Episode 830:
# 	steps done = 276503 / 300000
# 	return = 1.0
# 	goal = True
#
#
# Episode 840:
# 	steps done = 277449 / 300000
# 	return = 34.0
# 	goal = True
#
#
# Episode 850:
# 	steps done = 278328 / 300000
# 	return = 38.0
# 	goal = True
#
#
# 	Running_Average = -166.47058823529412
#
#
# Episode 860:
# 	steps done = 279395 / 300000
# 	return = 11.0
# 	goal = True
#
#
# Episode 870:
# 	steps done = 280484 / 300000
# 	return = 11.0
# 	goal = True
#
#
# Episode 880:
# 	steps done = 281511 / 300000
# 	return = 31.0
# 	goal = True
#
#
# Episode 890:
# 	steps done = 282602 / 300000
# 	return = 57.0
# 	goal = True
#
#
# Episode 900:
# 	steps done = 283430 / 300000
# 	return = 78.0
# 	goal = True
#
#
# 	Running_Average = -155.13333333333333
#
#
# Episode 910:
# 	steps done = 284259 / 300000
# 	return = 177.0
# 	goal = True
#
#
# Episode 920:
# 	steps done = 285375 / 300000
# 	return = 33.0
# 	goal = True
#
#
# Episode 930:
# 	steps done = 286095 / 300000
# 	return = 79.0
# 	goal = True
#
#
# Episode 940:
# 	steps done = 286708 / 300000
# 	return = 152.0
# 	goal = True
#
#
# Episode 950:
# 	steps done = 287351 / 300000
# 	return = 110.0
# 	goal = True
#
#
# 	Running_Average = -141.16842105263157
#
#
# Episode 960:
# 	steps done = 288073 / 300000
# 	return = 127.0
# 	goal = True
#
#
# Episode 970:
# Episode 890: 57.0
# Episode 900: 78.0
# Episode 910: 177.0
# Episode 920: 33.0
# Episode 930: 79.0
# Episode 940: 152.0
# Episode 950: 110.0
# Episode 960: 127.0
# Episode 970: 168.0
# Episode 980: 138.0
# Episode 990: 179.0
# Episode 1000: 161.0
#
# -347.0
# -965.0
# -150.0
# -1029.0
# -40.0
# -204.0
# -907.0
# -360.0
# -534.0
# -684.0
# -485.0
# -624.0
# -194.0
# -526.0
# 0.0
# -71.0
# -538.0
# -339.0
# -541.0
# -397.0
# 23.0
# -112.0
# 1.0
# -316.0
# -369.0
# -9.0
# -262.0
# 57.0
# -158.0
# 33.0
# -119.0
# -106.0
# -23.0
# 61.0
# -147.0
# -102.0
# -187.0
# 39.0
# 34.0
# -1.0
# -34.0
# -69.0
# -67.0
# -310.0
# -26.0
# -9.0
# -348.0
# -278.0
# -119.0
# -338.0
# -155.0
# -186.0
# -78.0
# -263.0
# -237.0
# -118.0
# -33.0
# -146.0
# -19.0
# -136.0
# -129.0
# -201.0
# -221.0
# -179.0
# -35.0
# 81.0
# 96.0
# 64.0
# -114.0
# -110.0
# -105.0
# -169.0
# 28.0
# 124.0
# -259.0
# 136.0
# -21.0
# 157.0
# 122.0
# -26.0
# 95.0
# 10.0
# 1.0
# 34.0
# 38.0
# 11.0
# 11.0
# 31.0
# 57.0
# 78.0
# 177.0
# 33.0
# 79.0
# 152.0
# 110.0
# 127.0
# 168.0
# 138.0
# 179.0
# 161.0
#
# Episode 1010:
# 	steps done = 290810 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1020:
# 	steps done = 290935 / 300000
# 	return = 173.0
# 	goal = True
#
#
# Episode 1030:
# 	steps done = 291075 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1040:
# 	steps done = 291209 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1050:
# 	steps done = 291346 / 300000
# 	return = 181.0
# 	goal = True
#
#
# 	Running_Average = -111.86666666666666
#
#
# Episode 1060:
# 	steps done = 291503 / 300000
# 	return = 163.0
# 	goal = True
#
#
# Episode 1070:
# 	steps done = 291644 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1080:
# 	steps done = 291790 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1090:
# 	steps done = 291956 / 300000
# 	return = 172.0
# 	goal = True
#
#
# Episode 1100:
# 	steps done = 292093 / 300000
# 	return = 178.0
# 	goal = True
#
#
# 	Running_Average = -98.88181818181818
#
#
# Episode 1110:
# 	steps done = 292238 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1120:
# 	steps done = 292360 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1130:
# 	steps done = 292510 / 300000
# 	return = 174.0
# 	goal = True
#
#
# Episode 1140:
# 	steps done = 292636 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 1150:
# 	steps done = 292779 / 300000
# 	return = 181.0
# 	goal = True
#
#
# 	Running_Average = -86.85217391304347
#
#
# Episode 1160:
# 	steps done = 292927 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1170:
# 	steps done = 293058 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1180:
# 	steps done = 293189 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1190:
# 	steps done = 293316 / 300000
# 	return = 169.0
# 	goal = True
#
#
# Episode 1200:
# 	steps done = 293443 / 300000
# 	return = 175.0
# 	goal = True
#
#
# 	Running_Average = -75.89166666666667
#
#
# Episode 1210:
# 	steps done = 293574 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1220:
# 	steps done = 293702 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1230:
# 	steps done = 293858 / 300000
# 	return = 166.0
# 	goal = True
#
#
# Episode 1240:
# 	steps done = 294011 / 300000
# 	return = 164.0
# 	goal = True
#
#
# Episode 1250:
# 	steps done = 294143 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -65.912
#
#
# Episode 1260:
# 	steps done = 294289 / 300000
# 	return = 159.0
# 	goal = True
#
#
# Episode 1270:
# 	steps done = 294412 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1280:
# 	steps done = 294539 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1290:
# 	steps done = 294654 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1300:
# 	steps done = 294774 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -56.60769230769231
#
#
# Episode 1310:
# 	steps done = 294888 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1320:
# 	steps done = 295008 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1330:
# 	steps done = 295136 / 300000
# 	return = 161.0
# 	goal = True
#
#
# Episode 1340:
# 	steps done = 295282 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1350:
# 	steps done = 295404 / 300000
# 	return = 172.0
# 	goal = True
#
#
# 	Running_Average = -48.0
#
#
# Episode 1360:
# 	steps done = 295522 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1370:
# 	steps done = 295641 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1380:
# 	steps done = 295753 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1390:
# 	steps done = 295909 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1400:
# 	steps done = 296046 / 300000
# 	return = 168.0
# 	goal = True
#
#
# 	Running_Average = -39.957142857142856
#
#
# Episode 1410:
# 	steps done = 296188 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1420:
# 	steps done = 296322 / 300000
# 	return = 164.0
# 	goal = True
#
#
# Episode 1430:
# 	steps done = 296460 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1440:
# 	steps done = 296593 / 300000
# 	return = 173.0
# 	goal = True
#
#
# Episode 1450:
# 	steps done = 296720 / 300000
# 	return = 164.0
# 	goal = True
#
#
# 	Running_Average = -32.703448275862065
#
#
# Episode 1460:
# 	steps done = 296852 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1470:
# 	steps done = 296986 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1480:
# 	steps done = 297157 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 1490:
# 	steps done = 297297 / 300000
# 	return = 156.0
# 	goal = True
#
#
# Episode 1500:
# 	steps done = 297432 / 300000
# 	return = 162.0
# 	goal = True
#
#
# 	Running_Average = -25.926666666666666
#
#
# Episode 1510:
# 	steps done = 297544 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 1520:
# 	steps done = 297666 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1530:
# 	steps done = 297795 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1540:
# 	steps done = 297948 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1550:
# 	steps done = 298091 / 300000
# 	return = 171.0
# 	goal = True
#
#
# 	Running_Average = -19.36774193548387
#
#
# Episode 1560:
# 	steps done = 298219 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1570:
# 	steps done = 298345 / 300000
# 	return = 165.0
# 	goal = True
#
#
# Episode 1580:
# 	steps done = 298479 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1590:
# 	steps done = 298599 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1600:
# 	steps done = 298719 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -13.225
#
#
# Episode 1610:
# 	steps done = 298858 / 300000
# 	return = 172.0
# 	goal = True
#
#
# Episode 1620:
# 	steps done = 299016 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1630:
# 	steps done = 299147 / 300000
# 	return = 164.0
# 	goal = True
#
#
# Episode 1640:
# 	steps done = 299267 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1650:
# 	steps done = 299390 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -7.539393939393939
#
#
# Episode 1660:
# 	steps done = 299543 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1670:
# 	steps done = 299690 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1680:
# 	steps done = 299818 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1690:
# 	steps done = 299968 / 300000
# 	return = 176.0
# 	goal = True
#
# Training complete
#
# Episode 1693:
# 	steps done = 300000 / 300000
# 	return = 83.0
# 	goal = False
#
# Running_Average List:
#
# Episode 50: -506.2
# Episode 100: -522.0
# Episode 150: -469.93333333333334
# Episode 200: -446.75
# Episode 250: -388.32
# Episode 300: -334.9
# Episode 350: -296.6
# Episode 400: -264.95
# Episode 450: -246.75555555555556
# Episode 500: -243.92
# Episode 550: -238.45454545454547
# Episode 600: -226.11666666666667
# Episode 650: -220.4923076923077
# Episode 700: -204.5
# Episode 750: -195.94666666666666
# Episode 800: -179.1
# Episode 850: -166.47058823529412
# Episode 900: -155.13333333333333
# Episode 950: -141.16842105263157
# Episode 1000: -126.38
# Episode 1050: -111.86666666666666
# Episode 1100: -98.88181818181818
# Episode 1150: -86.85217391304347
# Episode 1200: -75.89166666666667
# Episode 1250: -65.912
# Episode 1300: -56.60769230769231
# Episode 1350: -48.0
# Episode 1400: -39.957142857142856
# Episode 1450: -32.703448275862065
# Episode 1500: -25.926666666666666
# Episode 1550: -19.36774193548387
# Episode 1600: -13.225
# Episode 1650: -7.539393939393939
#
# Episode 10: -347.0
# Episode 20: -965.0
# Episode 30: -150.0
# Episode 40: -1029.0
# Episode 50: -40.0
# Episode 60: -204.0
# Episode 70: -907.0
# Episode 80: -360.0
# Episode 90: -534.0
# Episode 100: -684.0
# Episode 110: -485.0
# Episode 120: -624.0
# Episode 130: -194.0
# Episode 140: -526.0
# Episode 150: 0.0
# Episode 160: -71.0
# Episode 170: -538.0
# Episode 180: -339.0
#  'lr': 0.001,
#  'seed': None,
#  'self': <__main__.TabularQLearningAgent object at 0x7f45ec81ed70>,
#  'training_steps': 300000,
#  'verbose': 1}
#
# Starting training
#
# Episode 10:
# 	steps done = 4661 / 300000
# 	return = -484.0
# 	goal = True
#
#
# Episode 20:
# 	steps done = 12833 / 300000
# 	return = -989.0
# 	goal = False
#
#
# Episode 30:
# 	steps done = 20621 / 300000
# 	return = -650.0
# 	goal = True
#
#
# Episode 40:
# 	steps done = 26632 / 300000
# 	return = -1057.0
# 	goal = False
#
#
# Episode 50:
# 	steps done = 32220 / 300000
# 	return = -515.0
# 	goal = True
#
#
# 	Running_Average = -739.0
#
#
# Episode 60:
# 	steps done = 36623 / 300000
# 	return = -569.0
# 	goal = True
#
#
# Episode 70:
# 	steps done = 40585 / 300000
# 	return = -518.0
# 	goal = True
#
#
# Episode 80:
# 	steps done = 44334 / 300000
# 	return = -55.0
# 	goal = True
#
#
# Episode 90:
# 	steps done = 48523 / 300000
# 	return = -155.0
# 	goal = True
#
#
# Episode 100:
# 	steps done = 53534 / 300000
# 	return = -625.0
# 	goal = True
#
#
# 	Running_Average = -561.7
#
#
# Episode 110:
# 	steps done = 57306 / 300000
# 	return = -92.0
# 	goal = True
#
#
# Episode 120:
# 	steps done = 61401 / 300000
# 	return = -60.0
# 	goal = True
#
#
# Episode 130:
# 	steps done = 65528 / 300000
# 	return = -89.0
# 	goal = True
#
#
# Episode 140:
# 	steps done = 69417 / 300000
# 	return = 44.0
# 	goal = True
#
#
# Episode 150:
# 	steps done = 73352 / 300000
# 	return = -23.0
# 	goal = True
#
#
# 	Running_Average = -389.1333333333333
#
#
# Episode 160:
# 	steps done = 77406 / 300000
# 	return = -3.0
# 	goal = True
#
#
# Episode 170:
# 	steps done = 81326 / 300000
# 	return = -420.0
# 	goal = True
#
#
# Episode 180:
# 	steps done = 85026 / 300000
# 	return = -247.0
# 	goal = True
#
#
# Episode 190:
# 	steps done = 87633 / 300000
# 	return = -203.0
# 	goal = True
#
#
# Episode 200:
# 	steps done = 90474 / 300000
# 	return = 38.0
# 	goal = True
#
#
# 	Running_Average = -333.6
#
#
# Episode 210:
# 	steps done = 94164 / 300000
# 	return = -265.0
# 	goal = True
#
#
# Episode 220:
# 	steps done = 96774 / 300000
# 	return = -95.0
# 	goal = True
#
#
# Episode 230:
# 	steps done = 100179 / 300000
# 	return = -24.0
# 	goal = True
#
#
# Episode 240:
# 	steps done = 102868 / 300000
# 	return = 23.0
# 	goal = True
#
#
# Episode 250:
# 	steps done = 105248 / 300000
# 	return = -78.0
# 	goal = True
#
#
# 	Running_Average = -284.44
#
#
# Episode 260:
# 	steps done = 108082 / 300000
# 	return = -411.0
# 	goal = True
#
#
# Episode 270:
# 	steps done = 111069 / 300000
# 	return = -20.0
# 	goal = True
#
#
# Episode 280:
# 	steps done = 113896 / 300000
# 	return = 28.0
# 	goal = True
#
#
# Episode 290:
# 	steps done = 116203 / 300000
# 	return = 35.0
# 	goal = True
#
#
# Episode 300:
# 	steps done = 119294 / 300000
# 	return = -84.0
# 	goal = True
#
#
# 	Running_Average = -252.1
#
#
# Episode 310:
# 	steps done = 122493 / 300000
# 	return = -225.0
# 	goal = True
#
#
# Episode 320:
# 	steps done = 124690 / 300000
# 	return = -5.0
# 	goal = True
#
#
# Episode 330:
# 	steps done = 128188 / 300000
# 	return = -503.0
# 	goal = True
#
#
# Episode 340:
# 	steps done = 130824 / 300000
# 	return = -53.0
# 	goal = True
#
#
# Episode 350:
# 	steps done = 133083 / 300000
# 	return = 60.0
# 	goal = True
#
#
# 	Running_Average = -236.82857142857142
#
#
# Episode 360:
# 	steps done = 135504 / 300000
# 	return = 14.0
# 	goal = True
#
#
# Episode 370:
# 	steps done = 137848 / 300000
# 	return = 66.0
# 	goal = True
#
#
# Episode 380:
# 	steps done = 139947 / 300000
# 	return = 35.0
# 	goal = True
#
#
# Episode 390:
# 	steps done = 142827 / 300000
# 	return = 158.0
# 	goal = True
#
#
# Episode 400:
# 	steps done = 145137 / 300000
# 	return = -188.0
# 	goal = True
#
#
# 	Running_Average = -205.1
#
#
# Episode 410:
# 	steps done = 147330 / 300000
# 	return = -216.0
# 	goal = True
#
#
# Episode 420:
# 	steps done = 150142 / 300000
# 	return = -496.0
# 	goal = True
#
#
# Episode 430:
# 	steps done = 153120 / 300000
# 	return = -42.0
# 	goal = True
#
#
# Episode 440:
# 	steps done = 155289 / 300000
# 	return = -334.0
# 	goal = True
#
#
# Episode 450:
# 	steps done = 157974 / 300000
# 	return = -161.0
# 	goal = True
#
#
# 	Running_Average = -210.06666666666666
#
#
# Episode 460:
# 	steps done = 160968 / 300000
# 	return = -239.0
# 	goal = True
#
#
# Episode 470:
# 	steps done = 163208 / 300000
# 	return = 105.0
# 	goal = True
#
#
# Episode 480:
# 	steps done = 165681 / 300000
# 	return = -373.0
# 	goal = True
#
#
# Episode 490:
# 	steps done = 169074 / 300000
# 	return = -64.0
# 	goal = True
#
#
# Episode 500:
# 	steps done = 172428 / 300000
# 	return = -196.0
# 	goal = True
#
#
# 	Running_Average = -204.4
#
#
# Episode 510:
# 	steps done = 175341 / 300000
# 	return = -365.0
# 	goal = True
#
#
# Episode 520:
# 	steps done = 178718 / 300000
# 	return = -223.0
# 	goal = True
#
#
# Episode 530:
# 	steps done = 182289 / 300000
# 	return = -61.0
# 	goal = True
#
#
# Episode 540:
# 	steps done = 185051 / 300000
# 	return = -47.0
# 	goal = True
#
#
# Episode 550:
# 	steps done = 187781 / 300000
# 	return = -80.0
# 	goal = True
#
#
# 	Running_Average = -199.92727272727274
#
#
# Episode 560:
# 	steps done = 190709 / 300000
# 	return = -18.0
# 	goal = True
#
#
# Episode 570:
# 	steps done = 194338 / 300000
# 	return = -408.0
# 	goal = True
#
#
# Episode 580:
# 	steps done = 196968 / 300000
# 	return = -90.0
# 	goal = True
#
#
# Episode 590:
# 	steps done = 199843 / 300000
# 	return = -36.0
# 	goal = True
#
#
# Episode 600:
# 	steps done = 202328 / 300000
# 	return = -58.0
# 	goal = True
#
#
# 	Running_Average = -193.43333333333334
#
#
# Episode 610:
# 	steps done = 204448 / 300000
# 	return = -62.0
# 	goal = True
#
#
# Episode 620:
# 	steps done = 207114 / 300000
# 	return = 26.0
# 	goal = True
#
#
# Episode 630:
# 	steps done = 210197 / 300000
# 	return = 27.0
# 	goal = True
#
#
# Episode 640:
# 	steps done = 212594 / 300000
# 	return = -102.0
# 	goal = True
#
#
# Episode 650:
# 	steps done = 215140 / 300000
# 	return = 46.0
# 	goal = True
#
#
# 	Running_Average = -179.55384615384617
#
#
# Episode 660:
# 	steps done = 217139 / 300000
# 	return = 25.0
# 	goal = True
#
#
# Episode 670:
# 	steps done = 218739 / 300000
# 	return = 65.0
# 	goal = True
#
#
# Episode 680:
# 	steps done = 220897 / 300000
# 	return = -236.0
# 	goal = True
#
#
# Episode 690:
# 	steps done = 223082 / 300000
# 	return = -3.0
# 	goal = True
#
#
# Episode 700:
# 	steps done = 224804 / 300000
# 	return = -16.0
# 	goal = True
#
#
# 	Running_Average = -169.0857142857143
#
#
# Episode 710:
# 	steps done = 227120 / 300000
# 	return = 75.0
# 	goal = True
#
#
# Episode 720:
# 	steps done = 228818 / 300000
# 	return = 77.0
# 	goal = True
#
#
# Episode 730:
# 	steps done = 230496 / 300000
# 	return = 28.0
# 	goal = True
#
#
# Episode 740:
# 	steps done = 231803 / 300000
# 	return = 173.0
# 	goal = True
#
#
# Episode 750:
# 	steps done = 232738 / 300000
# 	return = 107.0
# 	goal = True
#
#
# 	Running_Average = -151.68
#
#
# Episode 760:
# 	steps done = 233789 / 300000
# 	return = 117.0
# 	goal = True
#
#
# Episode 770:
# 	steps done = 235057 / 300000
# 	return = -13.0
# 	goal = True
#
#
# Episode 780:
# 	steps done = 236023 / 300000
# 	return = 65.0
# 	goal = True
#
#
# Episode 790:
# 	steps done = 237146 / 300000
# 	return = 96.0
# 	goal = True
#
#
# Episode 800:
# 	steps done = 238515 / 300000
# 	return = 77.0
# 	goal = True
#
#
# 	Running_Average = -137.925
#
#
# Episode 810:
# 	steps done = 239572 / 300000
# 	return = 23.0
# 	goal = True
#
#
# Episode 820:
# 	steps done = 240400 / 300000
# 	return = 137.0
# 	goal = True
#
#
# Episode 830:
# 	steps done = 241292 / 300000
# 	return = 156.0
# 	goal = True
#
#
# Episode 840:
# 	steps done = 242331 / 300000
# 	return = -7.0
# 	goal = True
#
#
# Episode 850:
# 	steps done = 243379 / 300000
# 	return = 53.0
# 	goal = True
#
#
# 	Running_Average = -125.55294117647058
#
#
# Episode 860:
# 	steps done = 244224 / 300000
# 	return = 27.0
# 	goal = True
#
#
# Episode 870:
# 	steps done = 245045 / 300000
# 	return = 55.0
# 	goal = True
#
#
# Episode 880:
# 	steps done = 245829 / 300000
# 	return = 85.0
# 	goal = True
#
#
# Episode 890:
# 	steps done = 246535 / 300000
# 	return = 158.0
# 	goal = True
#
#
# Episode 900:
# 	steps done = 247457 / 300000
# 	return = 177.0
# 	goal = True
#
#
# 	Running_Average = -113.0
#
#
# Episode 910:
# 	steps done = 248145 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 920:
# 	steps done = 248817 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 930:
# 	steps done = 249292 / 300000
# 	return = 136.0
# 	goal = True
#
#
# Episode 940:
# 	steps done = 249904 / 300000
# 	return = 149.0
# 	goal = True
#
#
# Episode 950:
# 	steps done = 250266 / 300000
# 	return = 152.0
# 	goal = True
#
#
# 	Running_Average = -98.77894736842106
#
#
# Episode 960:
# 	steps done = 250708 / 300000
# 	return = 156.0
# 	goal = True
#
#
# Episode 970:
# 	steps done = 250854 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 980:
# 	steps done = 251074 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 990:
# 	steps done = 251237 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 1000:
# 	steps done = 251381 / 300000
# 	return = 173.0
# 	goal = True
#
#
# 	Running_Average = -85.37
#
# Episode 50: -739.0
# Episode 100: -561.7
# Episode 150: -389.1333333333333
# Episode 200: -333.6
# Episode 250: -284.44
# Episode 300: -252.1
# Episode 350: -236.82857142857142
# Episode 400: -205.1
# Episode 450: -210.06666666666666
# Episode 500: -204.4
# Episode 550: -199.92727272727274
# Episode 600: -193.43333333333334
# Episode 650: -179.55384615384617
# Episode 700: -169.0857142857143
# Episode 750: -151.68
# Episode 800: -137.925
# Episode 850: -125.55294117647058
# Episode 900: -113.0
# Episode 950: -98.77894736842106
# Episode 1000: -85.37
#
# Episode 10: -484.0
# Episode 20: -989.0
# Episode 30: -650.0
# Episode 40: -1057.0
# Episode 50: -515.0
# Episode 60: -569.0
# Episode 70: -518.0
# Episode 80: -55.0
# Episode 90: -155.0
# Episode 100: -625.0
# Episode 110: -92.0
# Episode 120: -60.0
# Episode 130: -89.0
# Episode 140: 44.0
# Episode 150: -23.0
# Episode 160: -3.0
# Episode 170: -420.0
# Episode 180: -247.0
# Episode 190: -203.0
# Episode 200: 38.0
# Episode 210: -265.0
# Episode 220: -95.0
# Episode 230: -24.0
# Episode 240: 23.0
# Episode 250: -78.0
# Episode 260: -411.0
# Episode 270: -20.0
# Episode 280: 28.0
# Episode 290: 35.0
# Episode 300: -84.0
# Episode 310: -225.0
# Episode 320: -5.0
# Episode 330: -503.0
# Episode 340: -53.0
# Episode 350: 60.0
# Episode 360: 14.0
# Episode 370: 66.0
# Episode 380: 35.0
# Episode 390: 158.0
# Episode 400: -188.0
# Episode 410: -216.0
# Episode 420: -496.0
# Episode 430: -42.0
# Episode 440: -334.0
# Episode 450: -161.0
# Episode 460: -239.0
# Episode 470: 105.0
# Episode 480: -373.0
# Episode 490: -64.0
# Episode 500: -196.0
# Episode 510: -365.0
# Episode 520: -223.0
# Episode 530: -61.0
# Episode 540: -47.0
# Episode 550: -80.0
# Episode 560: -18.0
# Episode 570: -408.0
# Episode 580: -90.0
# Episode 590: -36.0
# Episode 600: -58.0
# Episode 610: -62.0
# 	steps done = 252822 / 300000
# 	return = 180.0
# 	goal = True
#
#
# 	Running_Average = -61.49090909090909
#
#
# Episode 1110:
# 	steps done = 252983 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1120:
# 	steps done = 253124 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1130:
# 	steps done = 253260 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 1140:
# 	steps done = 253379 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1150:
# 	steps done = 253511 / 300000
# 	return = 175.0
# 	goal = True
#
#
# 	Running_Average = -51.12173913043478
#
#
# Episode 1160:
# 	steps done = 253645 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1170:
# 	steps done = 253773 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1180:
# 	steps done = 253893 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1190:
# 	steps done = 254022 / 300000
# 	return = 173.0
# 	goal = True
#
#
# Episode 1200:
# 	steps done = 254149 / 300000
# 	return = 179.0
# 	goal = True
#
#
# 	Running_Average = -41.59166666666667
#
#
# Episode 1210:
# 	steps done = 254281 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1220:
# 	steps done = 254409 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1230:
# 	steps done = 254516 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1240:
# 	steps done = 254640 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1250:
# 	steps done = 254758 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -32.696
#
#
# Episode 1260:
# 	steps done = 254888 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1270:
# 	steps done = 255005 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1280:
# 	steps done = 255123 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1290:
# 	steps done = 255289 / 300000
# 	return = 160.0
# 	goal = True
#
#
# Episode 1300:
# 	steps done = 255421 / 300000
# 	return = 172.0
# 	goal = True
#
#
# 	Running_Average = -24.73076923076923
#
#
# Episode 1310:
# 	steps done = 255546 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1320:
# 	steps done = 255694 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1330:
# 	steps done = 255840 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1340:
# 	steps done = 255981 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1350:
# 	steps done = 256096 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = -17.118518518518517
#
#
# Episode 1360:
# 	steps done = 256237 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1370:
# 	steps done = 256352 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1380:
# 	steps done = 256493 / 300000
# 	return = 174.0
# 	goal = True
#
#
# Episode 1390:
# 	steps done = 256622 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1400:
# 	steps done = 256750 / 300000
# 	return = 175.0
# 	goal = True
#
#
# 	Running_Average = -10.128571428571428
#
#
# Episode 1410:
# 	steps done = 256888 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 1420:
# 	steps done = 257030 / 300000
# 	return = 173.0
# 	goal = True
#
#
# Episode 1430:
# 	steps done = 257150 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1440:
# 	steps done = 257265 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1450:
# 	steps done = 257396 / 300000
# 	return = 174.0
# 	goal = True
#
#
# 	Running_Average = -3.7103448275862068
#
#
# Episode 1460:
# 	steps done = 257527 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1470:
# 	steps done = 257657 / 300000
# 	return = 153.0
# 	goal = True
#
#
# Episode 1480:
# 	steps done = 257779 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1490:
# 	steps done = 257918 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1500:
# 	steps done = 258052 / 300000
# 	return = 160.0
# 	goal = True
#
#
# 	Running_Average = 2.1066666666666665
#
#
# Episode 1510:
# 	steps done = 258169 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1520:
# 	steps done = 258301 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1530:
# 	steps done = 258430 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1540:
# 	steps done = 258564 / 300000
# 	return = 165.0
# 	goal = True
#
#
# Episode 1550:
# 	steps done = 258709 / 300000
# 	return = 170.0
# 	goal = True
#
#
# 	Running_Average = 7.716129032258064
#
#
# Episode 1560:
# 	steps done = 258839 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1570:
# 	steps done = 258951 / 300000
# 	return = 172.0
# 	goal = True
#
#
# Episode 1580:
# 	steps done = 259080 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1590:
# 	steps done = 259196 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1600:
# 	steps done = 259319 / 300000
# 	return = 180.0
# 	goal = True
#
#
# 	Running_Average = 13.04375
#
#
# Episode 1610:
# 	steps done = 259432 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1620:
# 	steps done = 259563 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 1630:
# 	steps done = 259712 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1640:
# 	steps done = 259821 / 300000
# 	return = 181.0
# 	goal = True
#
#
# Episode 1650:
# 	steps done = 259957 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = 18.072727272727274
#
#
# Episode 1660:
# 	steps done = 260099 / 300000
# 	return = 160.0
# 	goal = True
#
#
# Episode 1670:
# 	steps done = 260242 / 300000
# 	return = 165.0
# 	goal = True
#
#
# Episode 1680:
# 	steps done = 260360 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1690:
# 	steps done = 260524 / 300000
# 	return = 171.0
# 	goal = True
#
#
# Episode 1700:
# 	steps done = 260638 / 300000
# 	return = 176.0
# 	goal = True
#
#
# 	Running_Average = 22.564705882352943
#
#
# Episode 1710:
# 	steps done = 260767 / 300000
# 	return = 175.0
# 	goal = True
#
#
# Episode 1720:
# 	steps done = 260891 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1730:
# 	steps done = 261021 / 300000
# 	return = 185.0
# 	goal = True
#
#
# Episode 1740:
# 	steps done = 261138 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1750:
# 	steps done = 261263 / 300000
# 	return = 179.0
# 	goal = True
#
#
# 	Running_Average = 27.08
#
#
# Episode 1760:
# 	steps done = 261411 / 300000
# 	return = 178.0
# 	goal = True
#
#
# Episode 1770:
# 	steps done = 261543 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1780:
# 	steps done = 261688 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 1790:
# 	steps done = 261813 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1800:
# 	steps done = 261932 / 300000
# 	return = 175.0
# 	goal = True
#
#
# 	Running_Average = 31.255555555555556
#
#
# Episode 1810:
# 	steps done = 262056 / 300000
# 	return = 174.0
# 	goal = True
#
#
# Episode 1820:
# 	steps done = 262188 / 300000
# 	return = 163.0
# 	goal = True
#
#
# Episode 1830:
# 	steps done = 262317 / 300000
# 	return = 167.0
# 	goal = True
#
#
# Episode 1840:
# 	steps done = 262460 / 300000
# 	return = 174.0
# 	goal = True
#
#
# Episode 1850:
# 	steps done = 262580 / 300000
# 	return = 181.0
# 	goal = True
#
#
# 	Running_Average = 35.054054054054056
#
#
# Episode 1860:
# 	steps done = 262706 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1870:
# 	steps done = 262850 / 300000
# 	return = 176.0
# 	goal = True
#
#
# Episode 1880:
# 	steps done = 262997 / 300000
# 	return = 180.0
# 	goal = True
#
#
# Episode 1890:
# 	steps done = 263132 / 300000
# 	return = 172.0
# 	goal = True
#
#
# Episode 1900:
# 	steps done = 263259 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = 38.81578947368421
#
#
# Episode 1910:
# 	steps done = 263378 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1920:
# 	steps done = 263503 / 300000
# 	return = 170.0
# 	goal = True
#
#
# Episode 1930:
# 	steps done = 263646 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1940:
# 	steps done = 263778 / 300000
# 	return = 179.0
# 	goal = True
#
#
# Episode 1950:
# 	steps done = 263890 / 300000
# 	return = 182.0
# 	goal = True
#
#
# 	Running_Average = 42.41025641025641
#
#
# Episode 1960:
# 	steps done = 264005 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1970:
# 	steps done = 264121 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1980:
# 	steps done = 264256 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 1990:
# 	steps done = 264395 / 300000
# 	return = 182.0
# 	goal = True
#
#
# Episode 2000:
# 	steps done = 264529 / 300000
# 	return = 157.0
# 	goal = True
#
#
# 	Running_Average = 45.775
#
# Episode 50: -739.0
# Episode 100: -561.7
# Episode 150: -389.1333333333333
# Episode 200: -333.6
# Episode 250: -284.44
# Episode 300: -252.1
# Episode 350: -236.82857142857142
# Episode 400: -205.1
# Episode 450: -210.06666666666666
# Episode 500: -204.4
# Episode 550: -199.92727272727274
# Episode 600: -193.43333333333334
# Episode 650: -179.55384615384617
# Episode 700: -169.0857142857143
# Episode 750: -151.68
# Episode 800: -137.925
# Episode 850: -125.55294117647058
# Episode 900: -113.0
# Episode 950: -98.77894736842106
# Episode 1000: -85.37
# Episode 1050: -72.81904761904762
# Episode 1100: -61.49090909090909
# Episode 1150: -51.12173913043478
# Episode 1200: -41.59166666666667
# Episode 1250: -32.696
# Episode 1300: -24.73076923076923
# Episode 1350: -17.118518518518517
# Episode 1400: -10.128571428571428
# Episode 1450: -3.7103448275862068
# Episode 1500: 2.1066666666666665
# Episode 1550: 7.716129032258064
# Episode 1600: 13.04375
# Episode 1650: 18.072727272727274
# Episode 1700: 22.564705882352943
# Episode 1750: 27.08
# Episode 1800: 31.255555555555556
# Episode 1850: 35.054054054054056
# Episode 1900: 38.81578947368421
# Episode 1950: 42.41025641025641
# Episode 2000: 45.775
#
# Episode 10: -484.0
# Episode 20: -989.0
# Episode 30: -650.0
# Episode 40: -1057.0
# Episode 50: -515.0
# Episode 60: -569.0
# Episode 70: -518.0
# Episode 80: -55.0
# Episode 90: -155.0
# Episode 100: -625.0
# Episode 110: -92.0
# Episode 120: -60.0
# Episode 130: -89.0
# Episode 140: 44.0
#
# Starting training
#
# Episode 10:
# 	steps done = 806 / 300000
# 	return = -40.0
# 	goal = True
#
#
# Episode 20:
# 	steps done = 1642 / 300000
# 	return = -74.0
# 	goal = True
#
#
# Episode 30:
# 	steps done = 2081 / 300000
# 	return = -56.0
# 	goal = True
#
#
# Episode 40:
# 	steps done = 2489 / 300000
# 	return = -39.0
# 	goal = True
#
#
# Episode 50:
# 	steps done = 2901 / 300000
# 	return = -9.0
# 	goal = True
#
#
# 	Running_Average = -43.6
#
#
# Episode 60:
# 	steps done = 3511 / 300000
# 	return = -106.0
# 	goal = True
#
#
# Episode 70:
# 	steps done = 3884 / 300000
# 	return = -16.0
# 	goal = True
#
#
# Episode 80:
# 	steps done = 4147 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 90:
# 	steps done = 4390 / 300000
# 	return = -10.0
# 	goal = True
#
#
# Episode 100:
# 	steps done = 4591 / 300000
# 	return = -11.0
# 	goal = True
#
#
# 	Running_Average = -34.4
#
#
# Episode 110:
# 	steps done = 4845 / 300000
# 	return = -15.0
# 	goal = True
#
#
# Episode 120:
# 	steps done = 5033 / 300000
# 	return = -7.0
# 	goal = True
#
#
# Episode 130:
# 	steps done = 5287 / 300000
# 	return = -12.0
# 	goal = True
#
#
# Episode 140:
# 	steps done = 5448 / 300000
# 	return = -19.0
# 	goal = True
#
#
# Episode 150:
# 	steps done = 5634 / 300000
# 	return = 5.0
# 	goal = True
#
#
# 	Running_Average = -26.133333333333333
#
#
# Episode 160:
# 	steps done = 5860 / 300000
# 	return = 16.0
# 	goal = True
#
#
# Episode 170:
# 	steps done = 6006 / 300000
# 	return = -5.0
# 	goal = True
#
#
# Episode 180:
# 	steps done = 6172 / 300000
# 	return = 10.0
# 	goal = True
#
#
# Episode 190:
# 	steps done = 6329 / 300000
# 	return = -1.0
# 	goal = True
#
#
# Episode 200:
# 	steps done = 6504 / 300000
# 	return = -37.0
# 	goal = True
#
#
# 	Running_Average = -20.45
#
#
# Episode 210:
# 	steps done = 6647 / 300000
# 	return = 11.0
# 	goal = True
#
#
# Episode 220:
# 	steps done = 6794 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 230:
# 	steps done = 6917 / 300000
# 	return = 6.0
# 	goal = True
#
#
# Episode 240:
# 	steps done = 7016 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 250:
# 	steps done = 7147 / 300000
# 	return = 10.0
# 	goal = True
#
#
# 	Running_Average = -13.76
#
#
# Episode 260:
# 	steps done = 7241 / 300000
# 	return = 12.0
# 	goal = True
#
#
# Episode 270:
# 	steps done = 7302 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 280:
# 	steps done = 7359 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 290:
# 	steps done = 7449 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 300:
# 	steps done = 7542 / 300000
# 	return = 13.0
# 	goal = True
#
#
# 	Running_Average = -8.6
#
#
# Episode 310:
# 	steps done = 7617 / 300000
# 	return = 13.0
# 	goal = True
#
#
# Episode 320:
# 	steps done = 7711 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 330:
# 	steps done = 7780 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 340:
# 	steps done = 7876 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 350:
# 	steps done = 7929 / 300000
# 	return = 19.0
# 	goal = True
#
#
# 	Running_Average = -4.6571428571428575
#
#
# Episode 360:
# 	steps done = 7989 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 370:
# 	steps done = 8039 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 380:
# 	steps done = 8116 / 300000
# 	return = 15.0
# 	goal = True
#
#
# Episode 390:
# 	steps done = 8171 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 400:
# 	steps done = 8229 / 300000
# 	return = 16.0
# 	goal = True
#
#
# 	Running_Average = -1.725
#
#
# Episode 410:
# 	steps done = 8289 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 420:
# 	steps done = 8351 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 430:
# 	steps done = 8408 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 440:
# 	steps done = 8454 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 450:
# 	steps done = 8511 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 0.6444444444444445
#
#
# Episode 460:
# 	steps done = 8564 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 470:
# 	steps done = 8622 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 480:
# 	steps done = 8677 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 490:
# 	steps done = 8740 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 500:
# 	steps done = 8799 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 2.64
#
#
# Episode 510:
# 	steps done = 8847 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 520:
# 	steps done = 8898 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 530:
# 	steps done = 8959 / 300000
# 	return = 16.0
# 	goal = True
#
#
# Episode 540:
# 	steps done = 9012 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 550:
# 	steps done = 9067 / 300000
# 	return = 16.0
# 	goal = True
#
#
# 	Running_Average = 4.109090909090909
#
#
# Episode 560:
# 	steps done = 9114 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 570:
# 	steps done = 9168 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 580:
# 	steps done = 9219 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 590:
# 	steps done = 9270 / 300000
# 	return = 15.0
# 	goal = True
#
#
# Episode 600:
# 	steps done = 9312 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 5.383333333333334
#
#
# Episode 610:
# 	steps done = 9367 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 620:
# 	steps done = 9427 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 630:
# 	steps done = 9474 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 640:
# 	steps done = 9519 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 650:
# 	steps done = 9563 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 6.523076923076923
#
#
# Episode 660:
# 	steps done = 9605 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 670:
# 	steps done = 9657 / 300000
# 	return = 16.0
# 	goal = True
#
#
# Episode 680:
# 	steps done = 9702 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 690:
# 	steps done = 9746 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 700:
# 	steps done = 9791 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 7.428571428571429
#
#
# Episode 710:
# 	steps done = 9835 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 720:
# 	steps done = 9881 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 730:
# 	steps done = 9922 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 740:
# 	steps done = 9966 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 750:
# 	steps done = 10010 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 8.333333333333334
#
#
# Episode 760:
# 	steps done = 10051 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 770:
# 	steps done = 10092 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 780:
# 	steps done = 10137 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 790:
# 	steps done = 10184 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 800:
# 	steps done = 10227 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 9.0375
#
#
# Episode 810:
# 	steps done = 10271 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 820:
# 	steps done = 10311 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 830:
# 	steps done = 10354 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 840:
# 	steps done = 10405 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 850:
# 	steps done = 10448 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 9.705882352941176
#
#
# Episode 860:
# 	steps done = 10488 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 870:
# 	steps done = 10534 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 880:
# 	steps done = 10574 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode
# Episode 770: 21.0
# Episode 780: 18.0
# Episode 790: 17.0
# Episode 800: 21.0
# Episode 810: 21.0
# Episode 820: 21.0
# Episode 830: 21.0
# Episode 840: 18.0
# Episode 850: 21.0
# Episode 860: 21.0
# Episode 870: 19.0
# Episode 880: 21.0
# Episode 890: 21.0
# Episode 900: 21.0
# Episode 910: 21.0
# Episode 920: 15.0
# Episode 930: 21.0
# Episode 940: 19.0
# Episode 950: 21.0
# Episode 960: 21.0
# Episode 970: 20.0
# Episode 980: 21.0
# Episode 990: 20.0
# Episode 1000: 21.0
#
# -40.0
# -74.0
# -56.0
# -39.0
# -9.0
# -106.0
# -16.0
# 17.0
# -10.0
# -11.0
# -15.0
# -7.0
# -12.0
# -19.0
# 5.0
# 16.0
# -5.0
# 10.0
# -1.0
# -37.0
# 11.0
# 17.0
# 6.0
# 21.0
# 10.0
# 12.0
# 21.0
# 21.0
# 19.0
# 13.0
# 13.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 15.0
# 21.0
# 16.0
# 21.0
# 18.0
# 18.0
# 20.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 20.0
# 16.0
# 21.0
# 21.0
# 19.0
# 15.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 20.0
# 16.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 15.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
#
# Episode 1010:
# 	steps done = 11153 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1020:
# 	steps done = 11193 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1030:
# 	steps done = 11237 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1040:
# 	steps done = 11278 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1050:
# 	steps done = 11326 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 11.733333333333333
#
#
# Episode 1060:
# 	steps done = 11373 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1070:
# 	steps done = 11413 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1080:
# 	steps done = 11459 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 1090:
# 	steps done = 11505 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1100:
# 	steps done = 11548 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 12.118181818181819
#
#
# Episode 1110:
# 	steps done = 11588 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1120:
# 	steps done = 11630 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 1130:
# 	steps done = 11672 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1140:
# 	steps done = 11715 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1150:
# 	steps done = 11756 / 300000
# 	return = 20.0
# 	goal = True
#
#
# 	Running_Average = 12.478260869565217
#
#
# Episode 1160:
# 	steps done = 11800 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1170:
# 	steps done = 11842 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1180:
# 	steps done = 11891 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 1190:
# 	steps done = 11936 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1200:
# 	steps done = 11976 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 12.8
#
#
# Episode 1210:
# 	steps done = 12016 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1220:
# 	steps done = 12061 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1230:
# 	steps done = 12102 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1240:
# 	steps done = 12150 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 1250:
# 	steps done = 12192 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 13.096
#
#
# Episode 1260:
# 	steps done = 12239 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1270:
# 	steps done = 12286 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1280:
# 	steps done = 12329 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1290:
# 	steps done = 12370 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1300:
# 	steps done = 12416 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 13.392307692307693
#
#
# Episode 1310:
# 	steps done = 12458 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1320:
# 	steps done = 12501 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 1330:
# 	steps done = 12541 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1340:
# 	steps done = 12586 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1350:
# 	steps done = 12633 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 13.651851851851852
#
#
# Episode 1360:
# 	steps done = 12673 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1370:
# 	steps done = 12716 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1380:
# 	steps done = 12762 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1390:
# 	steps done = 12806 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1400:
# 	steps done = 12846 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 13.914285714285715
#
#
# Episode 1410:
# 	steps done = 12889 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1420:
# 	steps done = 12929 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1430:
# 	steps done = 12970 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1440:
# 	steps done = 13018 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1450:
# 	steps done = 13060 / 300000
# 	return = 20.0
# 	goal = True
#
#
# 	Running_Average = 14.144827586206896
#
#
# Episode 1460:
# 	steps done = 13100 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1470:
# 	steps done = 13141 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1480:
# 	steps done = 13181 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1490:
# 	steps done = 13221 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1500:
# 	steps done = 13264 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 14.373333333333333
#
#
# Episode 1510:
# 	steps done = 13313 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1520:
# 	steps done = 13358 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1530:
# 	steps done = 13400 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 1540:
# 	steps done = 13447 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1550:
# 	steps done = 13489 / 300000
# 	return = 19.0
# 	goal = True
#
#
# 	Running_Average = 14.561290322580644
#
#
# Episode 1560:
# 	steps done = 13537 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1570:
# 	steps done = 13580 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1580:
# 	steps done = 13626 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 1590:
# 	steps done = 13667 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 1600:
# 	steps done = 13711 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 14.74375
#
#
# Episode 1610:
# 	steps done = 13759 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1620:
# 	steps done = 13806 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1630:
# 	steps done = 13846 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1640:
# 	steps done = 13894 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 1650:
# 	steps done = 13934 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 14.921212121212122
#
#
# Episode 1660:
# 	steps done = 13979 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1670:
# 	steps done = 14019 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1680:
# 	steps done = 14064 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 1690:
# 	steps done = 14104 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1700:
# 	steps done = 14145 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 15.08235294117647
#
#
# Episode 1710:
# 	steps done = 14191 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1720:
# 	steps done = 14231 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1730:
# 	steps done = 14273 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1740:
# 	steps done = 14321 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1750:
# 	steps done = 14362 / 300000
# 	return = 20.0
# 	goal = True
#
#
# 	Running_Average = 15.245714285714286
#
#
# Episode 1760:
# 	steps done = 14404 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1770:
# 	steps done = 14451 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 1780:
# 	steps done = 14500 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 1790:
# 	steps done = 14546 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1800:
# 	steps done = 14587 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 15.372222222222222
#
#
# Episode 1810:
# 	steps done = 14629 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1820:
# 	steps done = 14671 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1830:
# 	steps done = 14716 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1840:
# 	steps done = 14766 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1850:
# 	steps done = 14808 / 300000
# 	return = 20.0
# 	goal = True
#
#
# 	Running_Average = 15.518918918918919
#
#
# Episode 1860:
# 	steps done = 14848 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1870:
# 	steps done = 14889 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1880:
# 	steps done = 14933 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1890:
# 	steps done = 14978 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1900:
# 	steps done = 15019 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 15.663157894736843
#
#
# Episode 1910:
# 	steps done = 15059 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1920:
# 	steps done = 15103 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 1930:
# 	steps done = 15144 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 
# Episode 1780: 17.0
# Episode 1790: 21.0
# Episode 1800: 21.0
# Episode 1810: 21.0
# Episode 1820: 21.0
# Episode 1830: 21.0
# Episode 1840: 21.0
# Episode 1850: 20.0
# Episode 1860: 21.0
# Episode 1870: 21.0
# Episode 1880: 21.0
# Episode 1890: 21.0
# Episode 1900: 21.0
# Episode 1910: 21.0
# Episode 1920: 21.0
# Episode 1930: 21.0
# Episode 1940: 21.0
# Episode 1950: 16.0
# Episode 1960: 21.0
# Episode 1970: 18.0
# Episode 1980: 21.0
# Episode 1990: 21.0
# Episode 2000: 18.0
#
# -40.0
# -74.0
# -56.0
# -39.0
# -9.0
# -106.0
# -16.0
# 17.0
# -10.0
# -11.0
# -15.0
# -7.0
# -12.0
# -19.0
# 5.0
# 16.0
# -5.0
# 10.0
# -1.0
# -37.0
# 11.0
# 17.0
# 6.0
# 21.0
# 10.0
# 12.0
# 21.0
# 21.0
# 19.0
# 13.0
# 13.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 15.0
# 21.0
# 16.0
# 21.0
# 18.0
# 18.0
# 20.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 20.0
# 16.0
# 21.0
# 21.0
# 19.0
# 15.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 20.0
# 16.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 15.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 19.0
# 21.0
# 21.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 19.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 18.0
# 21.0
# 21.0
# 18.0
#
# Episode 2010:
# 	steps done = 15499 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2020:
# 	steps done = 15539 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2030:
# 	steps done = 15585 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2040:
# 	steps done = 15625 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2050:
# 	steps done = 15672 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.0
#
#
# Episode 2060:
# 	steps done = 15717 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2070:
# 	steps done = 15761 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2080:
# 	steps done = 15807 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2090:
# 	steps done = 15851 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2100:
# 	steps done = 15892 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.11904761904762
#
#
# Episode 2110:
# 	steps done = 15932 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2120:
# 	steps done = 15975 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2130:
# 	steps done = 16017 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2140:
# 	steps done = 16062 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2150:
# 	steps done = 16105 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.232558139534884
#
#
# Episode 2160:
# 	steps done = 16145 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2170:
# 	steps done = 16189 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2180:
# 	steps done = 16236 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2190:
# 	steps done = 16276 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2200:
# 	steps done = 16319 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.34090909090909
#
#
# Episode 2210:
# 	steps done = 16362 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2220:
# 	steps done = 16404 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2230:
# 	steps done = 16446 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2240:
# 	steps done = 16489 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2250:
# 	steps done = 16530 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.444444444444443
#
#
# Episode 2260:
# 	steps done = 16572 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 2270:
# 	steps done = 16618 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2280:
# 	steps done = 16664 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 2290:
# 	steps done = 16710 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2300:
# 	steps done = 16754 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.526086956521738
#
#
# Episode 2310:
# 	steps done = 16794 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2320:
# 	steps done = 16835 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2330:
# 	steps done = 16882 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2340:
# 	steps done = 16926 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2350:
# 	steps done = 16966 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.621276595744682
#
#
# Episode 2360:
# 	steps done = 17009 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 2370:
# 	steps done = 17049 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2380:
# 	steps done = 17089 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2390:
# 	steps done = 17131 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2400:
# 	steps done = 17184 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.708333333333332
#
#
# Episode 2410:
# 	steps done = 17227 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2420:
# 	steps done = 17271 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 2430:
# 	steps done = 17313 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2440:
# 	steps done = 17358 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2450:
# 	steps done = 17406 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.791836734693877
#
#
# Episode 2460:
# 	steps done = 17450 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2470:
# 	steps done = 17498 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2480:
# 	steps done = 17542 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2490:
# 	steps done = 17589 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2500:
# 	steps done = 17637 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.876
#
#
# Episode 2510:
# 	steps done = 17687 / 300000
# 	return = 14.0
# 	goal = True
#
#
# Episode 2520:
# 	steps done = 17729 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2530:
# 	steps done = 17771 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2540:
# 	steps done = 17811 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2550:
# 	steps done = 17853 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 16.929411764705883
#
#
# Episode 2560:
# 	steps done = 17900 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2570:
# 	steps done = 17943 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2580:
# 	steps done = 17989 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 2590:
# 	steps done = 18033 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2600:
# 	steps done = 18081 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.003846153846155
#
#
# Episode 2610:
# 	steps done = 18121 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2620:
# 	steps done = 18163 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2630:
# 	steps done = 18206 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2640:
# 	steps done = 18248 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2650:
# 	steps done = 18297 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.079245283018867
#
#
# Episode 2660:
# 	steps done = 18347 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2670:
# 	steps done = 18388 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2680:
# 	steps done = 18432 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2690:
# 	steps done = 18476 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2700:
# 	steps done = 18523 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.151851851851852
#
#
# Episode 2710:
# 	steps done = 18565 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2720:
# 	steps done = 18605 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2730:
# 	steps done = 18647 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2740:
# 	steps done = 18687 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2750:
# 	steps done = 18729 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.221818181818183
#
#
# Episode 2760:
# 	steps done = 18769 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2770:
# 	steps done = 18810 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2780:
# 	steps done = 18857 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2790:
# 	steps done = 18901 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2800:
# 	steps done = 18944 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.289285714285715
#
#
# Episode 2810:
# 	steps done = 18985 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2820:
# 	steps done = 19029 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2830:
# 	steps done = 19072 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2840:
# 	steps done = 19121 / 300000
# 	return = 18.0
# 	goal = True
#
#
# Episode 2850:
# 	steps done = 19163 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.343859649122805
#
#
# Episode 2860:
# 	steps done = 19203 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2870:
# 	steps done = 19243 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2880:
# 	steps done = 19284 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 2890:
# 	steps done = 19331 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 2900:
# 	steps done = 19374 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.396551724137932
#
#
# Episode 2910:
# 	steps done = 19418 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2920:
# 	steps done = 19468 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2930:
# 	steps done = 19510 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2940:
# 	steps done = 19552 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2950:
# 	steps done = 19599 / 300000
# 	return = 16.0
# 	goal = True
#
#
# 	Running_Average = 17.440677966101696
#
#
# Episode 2960:
# 	steps done = 19639 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2970:
# 	steps done = 19683 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2980:
# 	steps done = 19730 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 2990:
# 	steps done = 19774 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3000:
# 	steps done = 19823 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17
#
# -40.0
# -74.0
# -56.0
# -39.0
# -9.0
# -106.0
# -16.0
# 17.0
# -10.0
# -11.0
# -15.0
# -7.0
# -12.0
# -19.0
# 5.0
# 16.0
# -5.0
# 10.0
# -1.0
# -37.0
# 11.0
# 17.0
# 6.0
# 21.0
# 10.0
# 12.0
# 21.0
# 21.0
# 19.0
# 13.0
# 13.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 15.0
# 21.0
# 16.0
# 21.0
# 18.0
# 18.0
# 20.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 20.0
# 16.0
# 21.0
# 21.0
# 19.0
# 15.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 20.0
# 16.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 15.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 19.0
# 21.0
# 21.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 19.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 18.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 14.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 20.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
#
# Episode 3010:
# 	steps done = 19865 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3020:
# 	steps done = 19907 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3030:
# 	steps done = 19951 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3040:
# 	steps done = 19995 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3050:
# 	steps done = 20038 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.557377049180328
#
#
# Episode 3060:
# 	steps done = 20078 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3070:
# 	steps done = 20119 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 3080:
# 	steps done = 20165 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3090:
# 	steps done = 20208 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3100:
# 	steps done = 20259 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.60967741935484
#
#
# Episode 3110:
# 	steps done = 20302 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3120:
# 	steps done = 20350 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3130:
# 	steps done = 20394 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3140:
# 	steps done = 20439 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3150:
# 	steps done = 20479 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.663492063492065
#
#
# Episode 3160:
# 	steps done = 20526 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3170:
# 	steps done = 20571 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3180:
# 	steps done = 20617 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3190:
# 	steps done = 20658 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3200:
# 	steps done = 20707 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.715625
#
#
# Episode 3210:
# 	steps done = 20752 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3220:
# 	steps done = 20795 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3230:
# 	steps done = 20841 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3240:
# 	steps done = 20892 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 3250:
# 	steps done = 20939 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.753846153846155
#
#
# Episode 3260:
# 	steps done = 20987 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3270:
# 	steps done = 21033 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3280:
# 	steps done = 21077 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3290:
# 	steps done = 21119 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3300:
# 	steps done = 21162 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.803030303030305
#
#
# Episode 3310:
# 	steps done = 21206 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3320:
# 	steps done = 21254 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 3330:
# 	steps done = 21299 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 3340:
# 	steps done = 21346 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 3350:
# 	steps done = 21386 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.83582089552239
#
#
# Episode 3360:
# 	steps done = 21432 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3370:
# 	steps done = 21473 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 3380:
# 	steps done = 21517 / 300000
# 	return = 17.0
# 	goal = True
#
#
# Episode 3390:
# 	steps done = 21558 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3400:
# 	steps done = 21598 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.86764705882353
#
#
# Episode 3410:
# 	steps done = 21648 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3420:
# 	steps done = 21690 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3430:
# 	steps done = 21731 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3440:
# 	steps done = 21773 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3450:
# 	steps done = 21818 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 17.91304347826087
#
#
# Episode 3460:
# 	steps done = 21863 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 3470:
# 	steps done = 21907 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 
# Episode 8990: 21.0
# Episode 9000: 21.0
#
# -40.0
# -74.0
# -56.0
# -39.0
# -9.0
# -106.0
# -16.0
# 17.0
# -10.0
# -11.0
# -15.0
# -7.0
# -12.0
# -19.0
# 5.0
# 16.0
# -5.0
# 10.0
# -1.0
# -37.0
# 11.0
# 17.0
# 6.0
# 21.0
# 10.0
# 12.0
# 21.0
# 21.0
# 19.0
# 13.0
# 13.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 15.0
# 21.0
# 16.0
# 21.0
# 18.0
# 18.0
# 20.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 20.0
# 16.0
# 21.0
# 21.0
# 19.0
# 15.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 20.0
# 16.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 15.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 19.0
# 21.0
# 21.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 19.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 18.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 14.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 20.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 20.0
# 19.0
# 21.0
# 21.0
# 20.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 16.0
# 21.0
# 16.0
# 21.0
# 20.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 20.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 19.0
# 19.0
# 20.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 17.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 12.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 16.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 19.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 18.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 17.0
# 20.0
# 21.0
# 21.0
# 19.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 18.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 18.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 18.0
# 21.0
# 21.0
# 18.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 20.0
# 21.0
# 15.0
# 21.0
# 20.0
# 21.0
# 20.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 18.0
# 20.0
# 21.0
# 21.0
# 21.0
# 19.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 20.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
# 21.0
#
# Episode 9010:
# 	steps done = 46023 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9020:
# 	steps done = 46065 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 9030:
# 	steps done = 46105 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9040:
# 	steps done = 46148 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9050:
# 	steps done = 46192 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 19.61546961325967
#
#
# Episode 9060:
# 	steps done = 46235 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 9070:
# 	steps done = 46276 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9080:
# 	steps done = 46316 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9090:
# 	steps done = 46367 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9100:
# 	steps done = 46410 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 19.621978021978023
#
#
# Episode 9110:
# 	steps done = 46450 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9120:
# 	steps done = 46496 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9130:
# 	steps done = 46546 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 9140:
# 	steps done = 46589 / 300000
# 	return = 20.0
# 	goal = True
#
#
# Episode 9150:
# 	steps done = 46634 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 19.627322404371586
#
#
# Episode 9160:
# 	steps done = 46679 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9170:
# 	steps done = 46723 / 300000
# 	return = 19.0
# 	goal = True
#
#
# Episode 9180:
# 	steps done = 46765 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9190:
# 	steps done = 46807 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9200:
# 	steps done = 46847 / 300000
# 	return = 21.0
# 	goal = True
#
#
# 	Running_Average = 19.632608695652173
#
#
# Episode 9210:
# 	steps done = 46887 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9220:
# 	steps done = 46931 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9230:
# 	steps done = 46973 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9240:
# 	steps done = 47021 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9250:
# 	steps done = 47066 / 300000
# 	return = 19.0
# 	goal = True
#
#
# 	Running_Average = 19.63783783783784
#
#
# Episode 9260:
# 	steps done = 47109 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9270:
# 	steps done = 47149 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9280:
# 	steps done = 47191 / 300000
# 	return = 21.0
# 	goal = True
#
#
# Episode 9290:
# 	steps done = 47238 / 300000
# 	return = 21.0
# 	goal = True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 env3 = nasim.generate(**scenario_args2)
#       2 baseline_ql_agent2 = TabularQLearningAgent(env3, verbose=1, training_steps=300000) #10-20k steps, 10k episodes
# ----> 3 baseline_ql_agent2.train()
#       4 baseline_ql_agent2.run_eval_episode(render_mode="human")
#
# Cell In[3], line 168, in TabularQLearningAgent.train(self)
#     165 all_avgs = []
#     167 while self.steps_done < self.training_steps:
# --> 168     ep_results = self.run_train_episode(training_steps_remaining)
#     169     ep_return, ep_steps, goal = ep_results
#     170     num_episodes += 1
#
# Cell In[3], line 256, in TabularQLearningAgent.run_train_episode(self, step_limit)
#     253 while not done and not env_step_limit_reached and steps < step_limit:
#     254     a = self.get_egreedy_action(s, self.get_epsilon())
# --> 256     next_s, r, done, env_step_limit_reached, _ = self.env.step(a)
#     257     self.steps_done += 1
#     258     td_error, s_value = self.optimize(s, a, next_s, r, done)
#
# File ~/envs/nasim/lib/python3.10/site-packages/nasim/envs/environment.py:170, in NASimEnv.step(self, action)
#     143 def step(self, action):
#     144     """Run one step of the environment using action.
#     145
#     146     Implements gymnasium.Env.step().
#    (...)
#     168         (see :func:`nasim.env.action.ActionResult.info`)
#     169     """
# --> 170     next_state, obs, reward, done, info = self.generative_step(
#     171         self.current_state,
#     172         action
#     173     )
#     174     self.current_state = next_state
#     175     self.last_obs = obs
#
# File ~/envs/nasim/lib/python3.10/site-packages/nasim/envs/environment.py:220, in NASimEnv.generative_step(self, state, action)
#     217 if not isinstance(action, Action):
#     218     action = self.action_space.get_action(action)
# --> 220 next_state, action_obs = self.network.perform_action(
#     221     state, action
#     222 )
#     223 obs = next_state.get_observation(
#     224     action, action_obs, self.fully_obs
#     225 )
#     226 done = self.goal_reached(next_state)
#
# File ~/envs/nasim/lib/python3.10/site-packages/nasim/envs/network.py:57, in Network.perform_action(self, state, action)
#      54 assert 0 < tgt_subnet < len(self.subnets)
#      55 assert tgt_id <= self.subnets[tgt_subnet]
# ---> 57 next_state = state.copy()
#      59 if action.is_noop():
#      60     return next_state, ActionResult(True)
#
# File ~/envs/nasim/lib/python3.10/site-packages/nasim/envs/state.py:97, in State.copy(self)
#      96 def copy(self):
# ---> 97     new_tensor = np.copy(self.tensor)
#      98     return State(new_tensor, self.host_num_map)
#
# File ~/envs/nasim/lib/python3.10/site-packages/numpy/lib/function_base.py:962, in copy(a, order, subok)
#     873 @array_function_dispatch(_copy_dispatcher)
#     874 def copy(a, order='K', subok=False):
#     875     """
#     876     Return an array copy of the given object.
#     877
#    (...)
#     960
#     961     """
# --> 962     return array(a, order=order, subok=subok, copy=True)
#
# KeyboardInterrupt:

# %%
baseline_dqn_agent.run_eval_episode(render_mode="human")
# Out:
# (-1014.0, 1000, False)

# %%
# Import necessary libraries, including which methods will be redefined
import nasim
import random
from nasim.envs.action import Action
from nasim.agents.dqn_agent import DQNAgent
from nasim.envs.environment import NASimEnv

# User-defined Python method to check whether the selected blocked_host is valid to select
def check_host_valid(self, blocked_host):
    if blocked_host == -1:
        return
    elif self.env.network.address_space[blocked_host] in self.env.network.get_sensitive_hosts():
        raise SensitiveHostRemovalException
    elif blocked_host == 0:
        raise PublicHostRemovalException
    else:
        return

# Setting the method
DQNAgent.check_host_valid = check_host_valid
    
# Redefining the DQNAgent run_train_episode method
def run_train_episode(self, step_limit):
        done = False
        env_step_limit_reached = False #Unnecessary now with loop below using steps < step_limit
        steps = 0
        episode_return = 0
        max_host_index = len(self.env.network.host_num_map) - 1
        
        # Choosing random host index to be invalid... try/catch loop until valid host selected to block. Note: If -1, no host will be marked invalid
        blocked_host = -1
        if self.steps_done > 0:
            while True:
                try:
                    blocked_host = random.randint(-1,max_host_index)
                    self.check_host_valid(blocked_host)
                    break
                except SensitiveHostRemovalException:
                    pass
                except PublicHostRemovalException:
                    pass
                
        o, _ = self.env.reset()
        
        # If you wanted to see which host was blocked... used for the logging
        print("Blocked host index:  " + str(blocked_host))
        
        while not done and not env_step_limit_reached: #steps < step_limit: #J: changed from env_step_limit_reached:     
            #J: steps continuously updated at the bottom and will break as soon as step limit is reached
            # Keep generating an action in the action space until it does not involve a blocked host
            while True:
                a = self.get_egreedy_action(o, self.get_epsilon())
                
                if blocked_host == -1:
                    break
                else:
                    action = self.env.action_space.get_action(a)
                    target_host_index = self.env.network.host_num_map[action.target]
                    if target_host_index != blocked_host:
                        break
                
            next_o, r, done, env_step_limit_reached, _ = self.env.step(a)
            self.replay.store(o, a, next_o, r, done)
            self.steps_done += 1
            loss, mean_v = self.optimize()
            
            o = next_o
            episode_return += r
            steps += 1

        return episode_return, steps, self.env.goal_reached()

# Setting the method
DQNAgent.run_train_episode = run_train_episode

# Training function... redefined because it wasn't converging originally
def train(self):
    if self.verbose:
        print("\nStarting training")

    num_episodes = 0
    training_steps_remaining = self.training_steps
    og_env = self.env
    
    elems_to_avg = []
    all_avgs = []
    
    while self.steps_done < self.training_steps:
        self.env = og_env
        ep_results = self.run_train_episode(training_steps_remaining)
        ep_return, ep_steps, goal = ep_results
        num_episodes += 1
        training_steps_remaining -= ep_steps

        self.logger.add_scalar("episode", num_episodes, self.steps_done)
        self.logger.add_scalar(
            "epsilon", self.get_epsilon(), self.steps_done
        )
        self.logger.add_scalar(
            "episode_return", ep_return, self.steps_done
        )
        self.logger.add_scalar(
            "episode_steps", ep_steps, self.steps_done
        )
        self.logger.add_scalar(
            "episode_goal_reached", int(goal), self.steps_done
        )

        if num_episodes % 10 == 0 and self.verbose:
            print(f"\nEpisode {num_episodes}:")
            print(f"\tsteps done = {self.steps_done} / "
                f"{self.training_steps}")
            print(f"\treturn = {ep_return}")
            print(f"\tgoal = {goal}")
            print(f"\t")
            
            elems_to_avg.append(ep_return) #Jacob edit
        
        if num_episodes % 50 == 0 and self.verbose:
            avg = (sum(elems_to_avg) / len(elems_to_avg))
            all_avgs.append(avg)
            
            print(f"\t")
            print(f"\tRunning_Average = {avg}")
            print(f"\t")
            
            print("Running_Average List:")
            print(f"\t")
            
            for i in range(len(all_avgs)):
                print("Episode " + str((i+1)*50), end=": ")
                print(all_avgs[i])
            print(f"\t")
                

    self.logger.close()
    if self.verbose:
            print("Training complete")
            print(f"\nEpisode {num_episodes}:")
            print(f"\tsteps done = {self.steps_done} / {self.training_steps}")
            print(f"\treturn = {ep_return}")
            print(f"\tgoal = {goal}")
            
            print(f"\t")
            print("Running_Average List:")
            print(f"\t")
            
            
            print("Running_Average List:")
            print(f"\t")
            
            for i in range(len(all_avgs)):
                print("Episode " + str((i+1)*50), end=": ")
                print(all_avgs[i])
            print(f"\t")
            
            for i in range(len(elems_to_avg)):
                print("Episode " + str((i+1)*10), end=": ")
                print(elems_to_avg[i])
            print(f"\t")
            
            for i in range(len(elems_to_avg)):
                print(elems_to_avg[i])
            print(f"\t")
            
            
            #plot_average_bar_chart(elems_to_avg)

# Set the method        
DQNAgent.train = train

# You can switch to a different benchmark if you want... like the scenario args posted or your own
env = nasim.make_benchmark("small")
#Liam does it this way: env = nasim.load("small.yaml")
# Initializing and training agent
dqn_agent = DQNAgent(env, verbose=1, training_steps=5000000)
dqn_agent.train()
# Out:
# Running DQN with config:
# {'batch_size': 32,
#  'env': <nasim.envs.environment.NASimEnv object at 0x7fb48a1bdd50>,
#  'exploration_steps': 10000,
#  'final_epsilon': 0.05,
#  'gamma': 0.99,
#  'hidden_sizes': [64, 64],
#  'kwargs': {},
#  'lr': 0.001,
#  'replay_size': 10000,
#  'seed': None,
#  'self': <nasim.agents.dqn_agent.DQNAgent object at 0x7fb3bfd09ea0>,
#  'target_update_freq': 1000,
#  'training_steps': 5000000,
#  'verbose': 1}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 176
#     173 env = nasim.make_benchmark("small")
#     174 #Liam does it this way: env = nasim.load("small.yaml")
#     175 # Initializing and training agent
# --> 176 dqn_agent = DQNAgent(env, verbose=1, training_steps=5000000)
#     177 dqn_agent.train()
#
# File ~/envs/nasim/lib/python3.10/site-packages/nasim/agents/dqn_agent.py:164, in DQNAgent.__init__(self, env, seed, lr, training_steps, batch_size, replay_size, final_epsilon, exploration_steps, gamma, hidden_sizes, target_update_freq, verbose, **kwargs)
#     158 # Neural Network related attributes
#     159 self.device = torch.device("cuda"
#     160                            if torch.cuda.is_available()
#     161                            else "cpu")
#     162 self.dqn = DQN(self.obs_dim,
#     163                hidden_sizes,
# --> 164                self.num_actions).to(self.device)
#     165 if self.verbose:
#     166     print(f"\nUsing Neural Network running on device={self.device}:")
#
# File ~/envs/nasim/lib/python3.10/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~/envs/nasim/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/envs/nasim/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/envs/nasim/lib/python3.10/site-packages/torch/nn/modules/module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File ~/envs/nasim/lib/python3.10/site-packages/torch/nn/modules/module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# KeyboardInterrupt:

# %%
dqn_agent.run_eval_episode(render=False)

# %% [markdown]
# ## Past Attempts

# %% [markdown]
# This was some code that didn't end up working if you wanted to see a previous attempt

# %%
import numpy as np

capacity = 10
s_dims = (5,)
s_buf = np.zeros((capacity, *s_dims), dtype=np.float32)
#test_tuple.resize(test_tuple, [3,2])

print(s_buf)

# %%
import nasim
import random
from nasim.agents.dqn_agent import DQNAgent

def run_train_episode(self, step_limit):
        done = False
        env_step_limit_reached = False
        steps = 0
        episode_return = 0
        
        o = self.env.reset()
        
        while not done and not env_step_limit_reached: #and steps < step_limit:
            a = self.get_egreedy_action(o, self.get_epsilon())
        
            next_o, r, done, env_step_limit_reached, _ = self.env.step(a)
            self.replay.store(o, a, next_o, r, done)
            self.steps_done += 1
            loss, mean_v = self.optimize()
            
            o = next_o
            episode_return += r
            steps += 1

        return episode_return, steps, self.env.goal_reached()
    
DQNAgent.run_train_episode = run_train_episode

def train(self):
    if self.verbose:
        print("\nStarting training")

    num_episodes = 0
    training_steps_remaining = self.training_steps
    max_hosts = (self.env.scenario.get_description())['Hosts']
    max_obs_dim = self.env.observation_space.shape
    
    while self.steps_done < self.training_steps:
        if self.steps_done > 0:
            print(self.env.network.address_space)
            print(self.env.network.host_num_map)
            print(self.env.network.subnets)
            print(self.env.network.topology)
            print(self.env.network.firewall)
            print(self.env.network.address_space)
            print(self.env.network.address_space_bounds)
            print(self.env.network.sensitive_addresses)
            print(self.env.network.sensitive_hosts)

            self.env.observation_space = prev_observation_space
            self.num_actions = prev_num_actions
            self.obs_dim = prev_obs_dim
            self.replay = ReplayMemory(prev_replay_size,
                                   #self.obs_dim,
                                   #self.device)
            
            prev_observation_space = self.env.observation_space
            prev_num_actions = self.num_actions
            prev_obs_dim = self.obs_dim
            prev_replay = self.replay
            
            scenario_args.update(num_hosts=random.randint(3,max_hosts))
            
            self.env =  nasim.generate(**scenario_args)
            self.env.observation_space = prev_observation_space
            self.num_actions = prev_num_actions
            self.obs_dim = prev_obs_dim
            self.replay = prev_replay
            
        ep_results = self.run_train_episode(training_steps_remaining)
        ep_return, ep_steps, goal = ep_results
        num_episodes += 1
        training_steps_remaining -= ep_steps

        self.logger.add_scalar("episode", num_episodes, self.steps_done)
        self.logger.add_scalar(
            "epsilon", self.get_epsilon(), self.steps_done
        )
        self.logger.add_scalar(
            "episode_return", ep_return, self.steps_done
        )
        self.logger.add_scalar(
            "episode_steps", ep_steps, self.steps_done
        )
        self.logger.add_scalar(
            "episode_goal_reached", int(goal), self.steps_done
        )

        if num_episodes % 10 == 0 and self.verbose:
            print(f"\nEpisode {num_episodes}:")
            print(f"\tsteps done = {self.steps_done} / "
                    f"{self.training_steps}")
            print(f"\treturn = {ep_return}")
            print(f"\tgoal = {goal}")

    self.logger.close()
    if self.verbose:
        print("Training complete")
        print(f"\nEpisode {num_episodes}:")
        print(f"\tsteps done = {self.steps_done} / {self.training_steps}")
        print(f"\treturn = {ep_return}")
        print(f"\tgoal = {goal}")
            
DQNAgent.train = train

print(scenario_args)
env = nasim.generate(**scenario_args)
dqn_agent = DQNAgent(env, verbose=1, training_steps=100000)
dqn_agent.train()
dqn_agent.run_eval_episode(render=args.render_eval)
